# %% [markdown]
# <a href="https://colab.research.google.com/github/HarinCoder/HarinCoder/blob/main/Harin_Day16_DIY_Answers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Problem Statement: Sales Data Analysis-ILoad the “sample_superstore.csv”dataset provided on LMS into a DataFrame, using the Matplotlib library, plot the following insights from the dataset:**
#
# 1.Compare the total sales for each category of products
# 2.Number of deals in each state of America

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('SampleSuperstore.csv')
display(df)

print("")

i= df.groupby('Category')['Sales'].sum()
display(i)


plt.bar(category_sales.index, category_sales.values)
plt.title('Total Sales by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Sales')
plt.show()

plt.bar(state_deals.index, state_deals.values)
plt.title('Number of Deals by State')
plt.xlabel('State')
plt.ylabel('Number of Deals')
plt.xticks(rotation=90)
plt.show()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# 2. Problem Statement: Data Grouping -IILoad the “sample_superstore.csv”dataset provided on LMS into a DataFrame; using the Seaborn library, plot the following insights from the dataset:1.PrintacorrelationmatrixbetweenPostalcode,Quantity,Sales,Discount,andProfit2.Plot thecorrelationmatrixusingaheatmap

# %%
import pandas as pd
import seaborn as sea

df = pd.read_csv('SampleSuperstore.csv')

cols = ['Postal Code', 'Quantity', 'Sales', 'Discount', 'Profit']
corr_matrix = df[cols].corr()
print(cols)
print(corr_matrix)

sea.heatmap(corr_matrix, annot=True)
# Out:
# ['Postal Code', 'Quantity', 'Sales', 'Discount', 'Profit']
#              Postal Code  Quantity     Sales  Discount    Profit
# Postal Code     1.000000  0.012761 -0.023854  0.058443 -0.029961
# Quantity        0.012761  1.000000  0.200795  0.008623  0.066253
# Sales          -0.023854  0.200795  1.000000 -0.028190  0.479064
# Discount        0.058443  0.008623 -0.028190  1.000000 -0.219487
# Profit         -0.029961  0.066253  0.479064 -0.219487  1.000000
