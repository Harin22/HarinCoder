# %% [markdown]
# <a href="https://colab.research.google.com/github/HarinCoder/HarinCoder/blob/main/Harin_DIY_Day15_answers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. **Problem Statement: Data Grouping -ILoad the “big_bang_theory.csv”dataset  provided  on  LMS  into  a  DataFrame, group the data based on column "directed_by"using the groupby()function and  the  grouped  DataFrame.  Now  alsoprint  all  the  episodes  and  the  data associated with them, which belongs to the director -Mark Cendroski**

# %%
import pandas as pd

df = pd.read_csv("big_bang_theory_episodes.csv")
display(df)
# Out:
#      season  episode_num_in_season  episode_num_overall  \
# 0         1                      1                    1
# 1         1                      2                    2
# 2         1                      3                    3
# 3         1                      4                    4
# 4         1                      5                    5
# ..      ...                    ...                  ...
# 274      12                     20                  275
# 275      12                     21                  276
# 276      12                     22                  277
# 277      12                     23                  278
# 278      12                     24                  279
#
#                           title       directed_by  \
# 0                         Pilot     James Burrows
# 1       The Big Bran Hypothesis   Mark Cendrowski
# 2     The Fuzzy Boots Corollary   Mark Cendrowski
# 3      The Luminous Fish Effect   Mark Cendrowski
# ...

# %% [markdown]
# Printing the first group from grouped DataFrame:

# %%
first_group = (df.groupby('directed_by').count())
                         
display(first_group)
# Out:
#                   season  episode_num_in_season  episode_num_overall  title  \
# directed_by
# Andrew D. Weyman       1                      1                    1      1
# Anthony Rich          12                     12                   12     12
# Gay Linvill            2                      2                    2      2
# Howard Murray          2                      2                    2      2
# James Burrows          1                      1                    1      1
# Joel Murray            1                      1                    1      1
# Kristy Cecil           2                      2                    2      2
# Mark Cendrowski      244                    244                  244    244
# Nikki Lorre            6                      6                    6      6
# Peter Chakos           7                      7                    7      7
# Ted Wass               1                      1                    1      1
#
# ...

# %% [markdown]
# Displaying the group related to director-Mark Cendrowski:

# %%
i = (df.groupby("directed_by").get_group("Mark Cendrowski"))

display(i)
# Out:
#      season  episode_num_in_season  episode_num_overall  \
# 1         1                      2                    2
# 2         1                      3                    3
# 3         1                      4                    4
# 5         1                      6                    6
# 6         1                      7                    7
# ..      ...                    ...                  ...
# 272      12                     18                  273
# 273      12                     19                  274
# 274      12                     20                  275
# 277      12                     23                  278
# 278      12                     24                  279
#
#                            title      directed_by  \
# 1        The Big Bran Hypothesis  Mark Cendrowski
# 2      The Fuzzy Boots Corollary  Mark Cendrowski
# 3       The Luminous Fish Effect  Mark Cendrowski
# 5      The Middle Earth Paradigm  Mark Cendrowski
# ...

# %% [markdown]
# **2. Problem Statement: Data Grouping -IILoad the “big_bang_theory.csv”dataset  provided  on  LMS  into  a  DataFrame; Group  the data based  on  two columns, "directed_by"and "written_by,"using the groupby()function and print  the  grouped DataFrame.Also,  print  the average viewers in the United Statesand thedirector andthewriter'sdetails**

# %%
import pandas as pd 

df = pd.read_csv("big_bang_theory_episodes.csv")
display(df)
# Out:
#      season  episode_num_in_season  episode_num_overall  \
# 0         1                      1                    1
# 1         1                      2                    2
# 2         1                      3                    3
# 3         1                      4                    4
# 4         1                      5                    5
# ..      ...                    ...                  ...
# 274      12                     20                  275
# 275      12                     21                  276
# 276      12                     22                  277
# 277      12                     23                  278
# 278      12                     24                  279
#
#                           title       directed_by  \
# 0                         Pilot     James Burrows
# 1       The Big Bran Hypothesis   Mark Cendrowski
# 2     The Fuzzy Boots Corollary   Mark Cendrowski
# 3      The Luminous Fish Effect   Mark Cendrowski
# ...

# %%
lm = (df.groupby(["directed_by", "written_by"]).mean())


display(lm)
display("its size is : ",lm.size)
display("its length is : ",len(lm))
# Out:
#                                                                      season  \
# directed_by      written_by
# Andrew D. Weyman Story by: Jennifer GlickmanTeleplay by: Dave Go...     1.0
# Anthony Rich     Chuck Lorre & Bill Prady & Lee Aronsohn & Steve...     3.0
#                  Story by: Bill Prady & Eric Kaplan & Jim Reynol...     7.0
#                  Story by: Chuck Lorre & Bill Prady & Dave Goets...     4.0
#                  Story by: Chuck Lorre & Bill Prady & Steve Holl...     5.0
# ...                                                                     ...
# Peter Chakos     Story by: Chuck Lorre & Eric Kaplan & Adam Fabe...     6.0
#                  Story by: Chuck Lorre & Jim Reynolds & Jeremy H...     7.0
#                  Story by: Chuck Lorre & Lee Aronsohn & Steven M...     3.0
#                  Story by: Chuck Lorre & Steven Molaro & Maria F...     4.0
# Ted Wass         Story by: Dave Goetsch & Steven MolaroTeleplay ...     1.0
#
# ...
