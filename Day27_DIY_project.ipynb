# %% [markdown]
# <a href="https://colab.research.google.com/github/HarinCoder/HarinCoder/blob/main/Day27_DIY_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Problem Statement:
#
# Inferential StatisticsLoad the wine dataset using the Sklearn library to a DataFrame and perform the following tasks:

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# Covert the datasetinto DataFrame using pandas

# %%
# Convert dataset to a DataFrame
wine_df = pd.DataFrame(df)
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# Generate a sample size of 50 and give a random state as 100

# %%
sample = wine_df.sample(n=50, random_state=100)
sample
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1254            7.8             0.700         0.06             1.9      0.079
# 1087            7.9             0.190         0.42             1.6      0.057
# 822             6.7             0.540         0.13             2.0      0.076
# 1514            6.9             0.840         0.21             4.1      0.074
# 902             7.4             0.635         0.10             2.4      0.080
# 1150            8.2             0.330         0.32             2.8      0.067
# 1441            7.4             0.785         0.19             5.2      0.094
# 354             6.1             0.210         0.40             1.4      0.066
# 1153            9.6             0.420         0.35             2.1      0.083
# 1005            6.8             0.360         0.32             1.8      0.067
# 929             8.7             0.330         0.38             3.3      0.063
# ...

# %%
x_bar = sample['alcohol'].mean()
s = sample['alcohol'].std()

x_bar
s
# Out:
# 1.0869143326131592
