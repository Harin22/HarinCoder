# %% [markdown]
# <a href="https://colab.research.google.com/github/HarinCoder/HarinCoder/blob/main/Realworld_Data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("startups.csv")
df
# Out:
# Alchemy                         2
# ByteDance                       1
# Alation                         1
# Marshmallow                     1
# Rec Room                        1
#                                ..
# Warby Parker                    1
# Wefox                           1
# Yixia Technology                1
# New York General Group, Inc.    1
# 5ire                            1
# Name: Company, Length: 657, dtype: int64

# %%
df['Company'].value_counts()
# Out:
# Alchemy                         2
# ByteDance                       1
# Alation                         1
# Marshmallow                     1
# Rec Room                        1
#                                ..
# Warby Parker                    1
# Wefox                           1
# Yixia Technology                1
# New York General Group, Inc.    1
# 5ire                            1
# Name: Company, Length: 657, dtype: int64

# %%
df.fillna("NaN")
# Out:
#      Unnamed: 0         Company Valuation(US$ billions)      Valuation date  \
# 0             0       ByteDance                     140       June 2022[13]
# 1             1          SpaceX                     127       June 2022[13]
# 2             2           Shein                     100       June 2022[13]
# 3             3          Stripe                      50      March 2023[13]
# 4             4           Canva                      40  September 2021[16]
# ..          ...             ...                     ...                 ...
# 653         653             Voi                      1+      April 2022[59]
# 654         654   Neo Financial                       1       May 2022[567]
# 655         655  Physics Wallah                     1.1      June 2022[568]
# 656         656         OneCard                    1.4+      July 2022[569]
# 657         657            5ire                    1.5+      July 2022[570]
#
#                    Industry Country/countries  \
# ...

# %%
df["Industry"].value_counts()
# Out:
# Financial technology                               71
# Software                                           50
# E-commerce                                         30
# Cybersecurity                                      23
# Artificial intelligence                            19
#                                                    ..
# Trucking                                            1
# Home improvement                                    1
# Superintelligence・Quantum computing・Metaverse       1
# Content management system                           1
# Environmental,_social,_and_corporate_governance     1
# Name: Industry, Length: 155, dtype: int64

# %%
df.groupby('Valuation(US$ billions)').describe().dropna()
# Out:
#                         Unnamed: 0                                        \
#                              count        mean        std    min     25%
# Valuation(US$ billions)
# 1                              6.0  632.333333  27.442060  588.0  617.75
# 1+                           163.0  565.907975  48.349909  484.0  524.50
# 1.05                           2.0  480.500000   0.707107  480.0  480.25
# 1.1                           16.0  492.500000  55.401564  466.0  469.75
# 1.2                           26.0  451.500000   7.648529  439.0  445.25
# ...                            ...         ...        ...    ...     ...
# 7.5                            2.0   72.500000   0.707107   72.0   72.25
# 8                              3.0   68.000000   1.000000   67.0   67.50
# 8.1                            2.0   65.500000   0.707107   65.0   65.25
# 8.7                            2.0   59.500000   0.707107   59.0   59.25
# ...
