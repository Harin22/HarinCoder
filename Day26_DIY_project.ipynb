# %% [markdown]
# <a href="https://colab.research.google.com/github/HarinCoder/HarinCoder/blob/main/Day26_DIY_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem Statement: Sampling Distribution-I
#
# A wine can be labeled as quality "7" and above only if the alcohol level is greater than 11.3%. If the level of alcohol is high, then the will taste sour enough; if the alcohol level is less than 11.3%, the wine might taste bitter. The quality controlperson is only allowed to open ten bottles froma batch of wine with quality "7" & "8"to ensure the levels are sufficient. Load  the “winequality-red.csv”data  into  a  DataFrame  and [erform  following tasks:

# %%
import numpy as np
import pandas as pd
import seaborn as sns

df = pd.read_csv("winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# Select a sample of ten bottles from quality "7" and "8" using numpy.random() function.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

sample = df[df['quality'].isin([7,8])].sample(10, random_state=42)
sample
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1459            7.9              0.20         0.35             1.7      0.054
# 1549            7.4              0.36         0.30             1.8      0.074
# 1008            8.9              0.35         0.40             3.6      0.110
# 1157            5.1              0.51         0.18             2.1      0.042
# 265            11.8              0.26         0.52             1.8      0.071
# 942            10.1              0.43         0.40             2.6      0.092
# 1192            7.2              0.25         0.37             2.5      0.063
# 588             5.0              0.42         0.24             2.0      0.060
# 1466            7.3              0.48         0.32             2.1      0.062
# 1010            8.9              0.28         0.45             1.7      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# To Find out the mean and standard deviation of the sample

# %%
import numpy as np
import pandas as pd
import seaborn as sns


sample_mean = sample['alcohol'].mean()
sample_std = sample['alcohol'].std()

print("Sample Mean:", sample_mean)
print("Sample Standard Deviation:", sample_std)
# Out:
# Sample Mean: 11.709999999999999
# Sample Standard Deviation: 1.326189193809759

# %% [markdown]
# To Plot the alcohol content available in the sample using a distplot

# %%
import numpy as np
import pandas as pd
import seaborn as sns

sns.distplot(sample['alcohol'])
# Out:
# <ipython-input-5-ec971bf43a29>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample['alcohol'])
# <Axes: xlabel='alcohol', ylabel='Density'>
